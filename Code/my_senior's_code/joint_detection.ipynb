# %%
import cv2
import mediapipe as mp
import numpy as np
import numpy as np
import matplotlib.pyplot as plt

mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_pose = mp.solutions.pose
n = 23 #num of joint 
coordinate = [[0 for i in range(3)] for j in range(23)]
real_coordinate = [[0 for i in range(3)] for j in range(23)]
x = [0 for i in range(23)]
y = [0 for i in range(23)]
x_r = [0 for i in range(23)]
y_r = [0 for i in range(23)]
base = 1 #start no. of picture
#print(coordinate)
L = ['NOSE', 'LEFT_SHOULDER', 'RIGHT_SHOULDER', 'LEFT_ELBOW', 'RIGHT_ELBOW', 'LEFT_WRIST', 'RIGHT_WRIST',
     'LEFT_PINKY', 'RIGHT_PINKY', 'LEFT_INDEX', 'RIGHT_INDEX', 'LEFT_THUMB', 'RIGHT_THUMB', 
     'LEFT_HIP', 'RIGHT_HIP', 'LEFT_KNEE', 'RIGHT_KNEE', 'LEFT_ANKLE', 'RIGHT_ANKLE',
     'LEFT_HEEL', 'RIGHT_HEEL', 'LEFT_FOOT_INDEX', 'RIGHT_FOOT_INDEX']

# For static images:
IMAGE_FILES = []
BG_COLOR = (192, 192, 192) # gray
with mp_pose.Pose(
    static_image_mode=True,
    model_complexity=2,
    enable_segmentation=True,
    min_detection_confidence=0.5) as pose:
  #for idx, file in enumerate(IMAGE_FILES):
  for i in range(1):#num of batch
    image = cv2.imread("C:/Users/Jing-Yuan/Downloads/keyframe1.png")

    #remember to add your own path

    image_height, image_width, _ = image.shape
    
    # Convert the BGR image to RGB before processing.
    results = pose.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

  
    coordinate[0][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.NOSE].x
    coordinate[0][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.NOSE].y
    coordinate[0][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.NOSE].z
    '''print("NOSE", results.pose_landmarks.landmark[mp_pose.PoseLandmark.NOSE].y)
    print("LEFT_SHOULDER", results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_SHOULDER].y)
    print("RIGHT_SHOULDER", results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_SHOULDER].y)
    print("LEFT_EYE", results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_EYE].y)
    print("RIGHT_EYE", results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_EYE].y)
    print("LEFT_ANKLE", results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ANKLE].y)
    print("RIGHT_ANKLE", results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ANKLE].y)'''
    

    coordinate[1][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_SHOULDER].x
    coordinate[1][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_SHOULDER].y
    coordinate[1][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_SHOULDER].z

    coordinate[2][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_SHOULDER].x
    coordinate[2][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_SHOULDER].y
    coordinate[2][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_SHOULDER].z

    coordinate[3][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ELBOW].x
    coordinate[3][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ELBOW].y
    coordinate[3][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ELBOW].z
    
    coordinate[4][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ELBOW].x
    coordinate[4][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ELBOW].y
    coordinate[4][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ELBOW].z
    
    coordinate[5][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_WRIST].x
    coordinate[5][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_WRIST].y
    coordinate[5][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_WRIST].z

    coordinate[6][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_WRIST].x
    coordinate[6][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_WRIST].y
    coordinate[6][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_WRIST].z

    coordinate[7][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_PINKY].x
    coordinate[7][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_PINKY].y
    coordinate[7][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_PINKY].z
    
    coordinate[8][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_PINKY].x
    coordinate[8][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_PINKY].y
    coordinate[8][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_PINKY].z
    
    coordinate[9][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_INDEX].x
    coordinate[9][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_INDEX].y
    coordinate[9][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_INDEX].z
    
    coordinate[10][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_INDEX].x
    coordinate[10][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_INDEX].y
    coordinate[10][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_INDEX].z
    
    coordinate[11][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_THUMB].x
    coordinate[11][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_THUMB].y
    #coordinate[11][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark_LEFT_THUMB].z

    coordinate[12][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_THUMB].x
    coordinate[12][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_THUMB].y
    #coordinate[12][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_THUMB].z
    
    coordinate[13][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_HIP].x
    coordinate[13][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_HIP].y
    coordinate[13][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_HIP].z

    coordinate[14][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HIP].x
    coordinate[14][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HIP].y
    coordinate[14][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HIP].z

    coordinate[15][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_KNEE].x
    coordinate[15][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_KNEE].y
    coordinate[15][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_KNEE].z
    
    coordinate[16][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_KNEE].x
    coordinate[16][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_KNEE].y
    coordinate[16][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_KNEE].z
    
    coordinate[17][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ANKLE].x
    coordinate[17][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ANKLE].y
    coordinate[17][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ANKLE].z

    coordinate[18][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ANKLE].x
    coordinate[18][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ANKLE].y
    coordinate[18][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ANKLE].z

    coordinate[19][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_HEEL].x
    coordinate[19][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_HEEL].y
    coordinate[19][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_HEEL].z
    
    coordinate[20][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HEEL].x
    coordinate[20][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HEEL].y
    coordinate[20][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HEEL].z
    
    coordinate[21][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_FOOT_INDEX].x
    coordinate[21][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_FOOT_INDEX].y
    coordinate[21][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_FOOT_INDEX].z
    
    coordinate[22][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_FOOT_INDEX].x
    coordinate[22][1] = 1-results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_FOOT_INDEX].y
    coordinate[22][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_FOOT_INDEX].z
    
    '''coordinate[11][0] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_SHOULDER].x
    coordinate[11][1] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_SHOULDER].y
    coordinate[11][2] = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_SHOULDER].z'''
    
    for i in range(23):
        print(coordinate[i])

    #print(coordinate)
    #print(coordinate[0][1])
    #print(coordinate[1][1])
    #print(coordinate[17][1])
    for i in range(23):
        real_coordinate[i][0] = coordinate[i][0] * image_width
        real_coordinate[i][1] = coordinate[i][1] * image_height
        real_coordinate[i][2] = coordinate[i][2]
        x[i] = real_coordinate[i][0]
        y[i] = real_coordinate[i][1]
    #print(real_coordinate)
    plt.scatter(x, y)
    plt.scatter(x[0], y[0], color = "red") #nose
     
    plt.plot([x[10], x[8]], [y[10], y[8]], color = "black")
    plt.plot([x[10], x[6]], [y[10], y[6]], color = "black")
    plt.plot([x[8], x[6]], [y[8], y[6]], color = "black")
    plt.plot([x[6], x[12]], [y[6], y[12]], color = "black")
    plt.plot([x[6], x[4]], [y[6], y[4]], color = "black")
    plt.plot([x[4], x[2]], [y[4], y[2]], color = "black") #left hand

    plt.plot([x[9], x[7]], [y[9], y[7]], color = "black")
    plt.plot([x[5], x[7]], [y[5], y[7]], color = "black")
    plt.plot([x[5], x[9]], [y[5], y[9]], color = "black")
    plt.plot([x[5], x[11]], [y[5], y[11]], color = "black")
    plt.plot([x[3], x[5]], [y[3], y[5]], color = "black")
    plt.plot([x[3], x[1]], [y[3], y[1]], color = "black") #right hand

    plt.plot([x[2], x[1]], [y[2], y[1]], color = "black")

    plt.plot([x[2], x[14]], [y[2], y[14]], color = "black")
    plt.plot([x[1], x[13]], [y[1], y[13]], color = "black")
    plt.plot([x[14], x[13]], [y[14], y[13]], color = "black")
    plt.plot([x[14], x[16]], [y[14], y[16]], color = "black")
    plt.plot([x[13], x[15]], [y[13], y[15]], color = "black")
    plt.plot([x[16], x[18]], [y[16], y[18]], color = "black")
    plt.plot([x[15], x[17]], [y[15], y[17]], color = "black")
    plt.plot([x[18], x[22]], [y[18], y[22]], color = "black")
    plt.plot([x[18], x[20]], [y[18], y[20]], color = "black")
    plt.plot([x[22], x[20]], [y[22], y[20]], color = "black")
    plt.plot([x[19], x[17]], [y[19], y[17]], color = "black")
    plt.plot([x[17], x[21]], [y[17], y[21]], color = "black")
    plt.plot([x[19], x[21]], [y[19], y[21]], color = "black")



    
    #plt.xlabel("X")
    #plt.ylabel("Y")
    #plt.title("Scatter Plot")
    plt.axis("equal")
    plt.axis('off')
    
    #remember to add your own path
    #plt.savefig('/content/gdrive/MyDrive/'+ str(base)+ '.jpg')
    # plt.savefig(r"D:\\111064555\\"+str(base)+ ".jpg")

    plt.show()
    
    base+=1
      

    if not results.pose_landmarks:
      #continue
      print(
        f'Nose coordinates: ('
        f'{results.pose_landmarks.landmark[mp_pose.PoseLandmark.NOSE].x * image_width}, '
        f'{results.pose_landmarks.landmark[mp_pose.PoseLandmark.NOSE].y * image_height})'
      )
    idx = 1
    annotated_image = image.copy()
    
    # Draw segmentation on the image.
    # To improve segmentation around boundaries, consider applying a joint
    # bilateral filter to "results.segmentation_mask" with "image".
    condition = np.stack((results.segmentation_mask,) * 3, axis=-1) > 0.1
    bg_image = np.zeros(image.shape, dtype=np.uint8)
    
    bg_image[:] = BG_COLOR
    annotated_image = np.where(condition, annotated_image, bg_image)
    # Draw pose landmarks on the image.
    mp_drawing.draw_landmarks(
        annotated_image,
        results.pose_landmarks,
        mp_pose.POSE_CONNECTIONS,
        landmark_drawing_spec=mp_drawing_styles.get_default_pose_landmarks_style())
# Out:
# [0.47455254197120667, 0.7446095645427704, -0.5694869160652161]
# [0.5844205617904663, 0.6638217568397522, -0.1228165253996849]
# [0.3748004138469696, 0.6644296646118164, 0.17926838994026184]
# [0.7552490234375, 0.6183375716209412, -0.16886550188064575]
# [0.2830680012702942, 0.6482126116752625, 0.5046144723892212]
# [0.8186237812042236, 0.719438225030899, -0.2897243797779083]
# [0.24332042038440704, 0.72224560379982, 0.6739994287490845]
# [0.8496896028518677, 0.7465278804302216, -0.33210963010787964]
# [0.23485976457595825, 0.7410289645195007, 0.6846571564674377]
# [0.8303122520446777, 0.7537593245506287, -0.3499404788017273]
# [0.2436906397342682, 0.7467721700668335, 0.653131365776062]
# [0.8076024055480957, 0.7432272434234619, 0]
# [0.25031864643096924, 0.740121454000473, 0]
# [0.4957965016365051, 0.4230901002883911, -0.11072889715433121]
# [0.3518015146255493, 0.43227827548980713, 0.11061601340770721]
# [0.5352838039398193, 0.251407265663147, -0.09830360114574432]
# ...
